# %%
from convLSTM_frame_pred import *
from convLSTM_frame_pred import generate_dataloader, image_prediction_comparison

import torch
from torch.autograd import Variable
import torch.nn.functional as f
from torch import nn

# %%
from convLSTM_dataset import *
from torch.utils.data import DataLoader

from torch.utils.data.dataset import random_split

# %%
batch_size, channels, height, width = 32, 2, 30, 30
hidden_size = 32  # 64           # hidden state size
lr = 1e-5     # learning rate
max_epoch = 400  # number of epochs

dataset_path = '../dataset/resample_skipping_stride1'
train_sampler, test_sampler, train_dataloader, test_dataloader = generate_dataloader(
    dataset_path, batch_size, n_class=4)
# Out:
# torch.Size([15, 2, 30, 30])

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
image_prediction_comparison(n_frames_ahead=5, dataloader=test_dataloader)
plt.style.use('seaborn')
# Out:
# Instantiating model...
# ConvLSTMCell(
#   (Gates_layer1): Conv2d(34, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (Gates_layer2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (Shrink): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# <img src="data:image/png;base64,..." width="720">
